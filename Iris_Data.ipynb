# %% [markdown]
# <a href="https://colab.research.google.com/github/achintiii/Data-Analysis/blob/main/Iris_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')


#Import Numpy and Pandas libraries. 
#Numpy adds support for large, multi-dimensinal arrays and matrics, mathematical functions.
#Pandas is a library for manipulating numerical tables and time series
#seaborn is aPython data visualization library based on matplotlib
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/iris.csv")

display(df.head(10))
display(df.tail(10))
df.SepalLength.head()
df['SepalLength'].head()
df.iloc[1]
df.iloc[1,1]
display(df.head())
display(df[df['Class']=='Iris-setosa']. describe ())
res = sns.scatterplot(data = df, x = "PetalWidth", y = "PetalLength", hue = "Class")
iris = sns.load_dataset("iris")
#sns.pairplot(iris)
sns.set(rc={'figure.figsize':(12,8)})
sns.set_theme(style="darkgrid")
ax = sns.boxplot(x="Class", y="PetalLength", data=df)
ax = sns.swarmplot (x="Class", y="PetalLength", data = df, color = ".2")
plt.ylabel("PetalLength (cm)", size=12)


df.info()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0         5.10        3.50         1.40        0.20  Iris-setosa
# 1         4.90        3.00         1.40        0.20  Iris-setosa
# 2         4.70        3.20         1.30        0.20  Iris-setosa
# 3         4.60        3.10         1.50        0.20  Iris-setosa
# 4         5.00        3.60         1.40        0.20  Iris-setosa
# 5         5.40        3.90         1.70        0.40  Iris-setosa
# 6         4.60        3.40         1.40        0.30  Iris-setosa
# 7         5.00        3.40         1.50        0.20  Iris-setosa
# 8         4.40        2.90         1.40        0.20  Iris-setosa
# 9         4.90        3.10         1.50        0.10  Iris-setosa
#      SepalLength  SepalWidth  PetalLength  PetalWidth           Class
# ...

# %% [markdown]
# # New Section

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0         5.10        3.50         1.40        0.20  Iris-setosa
# 1         4.90        3.00         1.40        0.20  Iris-setosa
# 2         4.70        3.20         1.30        0.20  Iris-setosa
# 3         4.60        3.10         1.50        0.20  Iris-setosa
# 4         5.00        3.60         1.40        0.20  Iris-setosa

# %%
# Summary stats of all numeric columns
pd.set_option('float_format', '{:.2f}'.format)
df.describe ()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count       150.00      150.00       150.00      150.00
# mean          5.84        3.05         3.76        1.20
# std           0.83        0.43         1.76        0.76
# min           4.30        2.00         1.00        0.10
# 25%           5.10        2.80         1.60        0.30
# 50%           5.80        3.00         4.35        1.30
# 75%           6.40        3.30         5.10        1.80
# max           7.90        4.40         6.90        2.50

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.set_theme(style="whitegrid")
gf=sns.scatterplot(data = df, x = "PetalWidth", y = "PetalLength", hue = "Class")
import matplotlib.pyplot as plt
# for legend text
gf.legend(fontsize=5)
plt.xlabel("PetalWidth", size=16)
plt.ylabel("PetalLength", size=16)
plt.title("PetalWidth vs. PetalLength", size=24)
# Out:
# Text(0.5, 1.0, 'PetalWidth vs. PetalLength')
