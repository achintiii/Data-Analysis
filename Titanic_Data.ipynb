# %% [markdown]
# <a href="https://colab.research.google.com/github/achintiii/Data-Analysis/blob/main/Titanic_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/train_new.csv")
display(df.head(10))
display(df.tail(10))
sns.pairplot(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %%
sns.histplot(data = df, x = "Fare", hue = "Survived", kde = "True", multiple = "stack")

# %%
sns.boxplot(data = df, y="Age", x="Survived", hue = "Survived")

# %%
sns.histplot(data = df, x = "Age", hue = "Survived", kde = "True", multiple = "dodge")

# %%
res = sns.scatterplot(data = df, x="Fare", y="Survived", hue="Survived")

# %%
res2 = sns.scatterplot(data = df, x="Age", y="Survived", hue = "Survived")

# %%
res3=sns.scatterplot(data = df, x="Pclass", y="Survived", hue="Survived")

# %%
sns.boxplot(data = df, y = "Fare", x = "Survived", hue="Survived")

# %%
sns.histplot(data = df, x= "Embarked", y = "Pclass", hue = "Survived")

# %%
sns.histplot(data = df, x="Embarked", y = "Fare", hue = "Survived")

# %%
sns.histplot(data = df, x= "Fare", hue = "Survived", kde = True)

# %%
sns.histplot(data = df, x="Fare", hue = "Survived", kde = True)

# %%
sns.boxplot(data = df, x="Pclass", y="Fare", hue = "Survived", showfliers = False)

# %%
sns.histplot(data = df, x="Fare", hue = "Survived", kde = True, log_scale= 10)
